# %%
from qccodec import decode
from qcdata import CalcType

from pathlib import Path

text = Path("/home/tns97255/coding/autodev/autostorage/notebooks/test/opt.log")

res = decode(program="orca", calctype=CalcType.optimization, stdout=text.read_text(), as_dict=True)
res
# Out:
# {'extras': {'program_version': '6.1.1'},
#  'orbital_basis': 'def2-SVP',
#  'auxj_basis': 'def2/J'}

# %%
from autostorage.parsers.registry import registry

registry.program_parsers(program="orca")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       1 from autostorage.parsers.registry import ParserRegistry
#       2
#       3 reg = ParserRegistry()
#       4
# ----> 5 reg.program_parsers(program="orca")
#
# File ~/coding/autodev/autostorage/src/autostorage/parsers/registry.py:109, in ParserRegistry.program_parsers(self, program, filetype, calctype)
#     107 if not parser_specs:
#     108     msg = f"No parsers registered for {program}."
# --> 109     raise ValueError(msg)
#     111 if filetype:
#     112     parser_specs = [ps for ps in parser_specs if ps.filetype == filetype]
#
# ValueError: No parsers registered for orca.
